# %% [markdown]
# # Full Project Web Scraping

# %%
import requests
import time 
import datetime
from bs4 import BeautifulSoup
import smtplib

# %%
# connect to website 

URL = 'https://www.amazon.com/Delicious-Sarcastic-Humor-Funny-Graphic/dp/B00NMFDR0K/ref=sr_1_1_sspa?crid=2X5DY12FOCUIJ&dib=eyJ2IjoiMSJ9.VGTFeqeQH4KU2idMzbU8jljeOFDnEcH8OXTn0EzSs820MTVb5Y_DYOXSU_g0eDg1AD3R8vcopAqo2eM5PBnv1Q5WRRjm8IJQaMl6qHFa4qmINH1O9ZwBeHUhNDnIBqXR3o1oSRJuacDNGau7FVvcdXFlJ7gSi6cM53r2XHn0_5jmyTfPxN0QLs4wuXaFiy-KJGsXHg0XEo4V_a8gfVye72sNbpsY54MVLf3YF42w6iM.OyGQt23YrzS3FOnNmsBmGdsv5x2csJsWCRDz1QCePh8&dib_tag=se&keywords=data%2Banalytics%2Bt-shirt&qid=1744995006&sprefix=data%2Banalytics%2Bt-shirt%2Caps%2C361&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'


web = requests.get(URL)
web
soup = BeautifulSoup(web.content , "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
using find function id
# Out:
#   Cell In[57], line 1
#     using find function id
#           ^
# SyntaxError: invalid syntax

# %%
title = soup.find(id='productTitle').get_text()
title

# %%
price = soup.find(class_= "a-price-whole").get_text()
price

# %%
print(title.strip()[:])
print(price)
print(type(price))
# Out:
# Pi Day T Shirt Kids Mens Graphic Math School Days Novelty Teachers Funny T-Shirt
# 13.
# <class 'str'>

# %%
import datetime 
today = datetime.date.today()
print(today)
# Out:
# 2025-04-19

# %%
import csv 

header = ['Title','Price','Date']
data = [title,price,today]

# type(data)
with open('AmazonWebScraperDataSets.csv','w',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv('AmazonWebScraperDataSets.csv')
df
# Out:
#                                                Title  Price        Date
# 0          Pi Day T Shirt Kids Mens Graphic Math ...   13.0  2025-04-19

# %%
# now we append data into csv

with open('AmazonWebScraperDataSets.csv','a+',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

def check_price():
    
   URL = 'https://www.amazon.com/Delicious-Sarcastic-Humor-Funny-Graphic/dp/B00NMFDR0K/ref=sr_1_1_sspa?crid=2X5DY12FOCUIJ&dib=eyJ2IjoiMSJ9.VGTFeqeQH4KU2idMzbU8jljeOFDnEcH8OXTn0EzSs820MTVb5Y_DYOXSU_g0eDg1AD3R8vcopAqo2eM5PBnv1Q5WRRjm8IJQaMl6qHFa4qmINH1O9ZwBeHUhNDnIBqXR3o1oSRJuacDNGau7FVvcdXFlJ7gSi6cM53r2XHn0_5jmyTfPxN0QLs4wuXaFiy-KJGsXHg0XEo4V_a8gfVye72sNbpsY54MVLf3YF42w6iM.OyGQt23YrzS3FOnNmsBmGdsv5x2csJsWCRDz1QCePh8&dib_tag=se&keywords=data%2Banalytics%2Bt-shirt&qid=1744995006&sprefix=data%2Banalytics%2Bt-shirt%2Caps%2C361&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'


   web = requests.get(URL)
   web
   soup = BeautifulSoup(web.content , "html.parser")
   soup
   title = soup.find(id='productTitle').get_text()
   # title
   price = soup.find(class_= "a-price-whole").get_text()
   # price
   print(title.strip()[:])
   print(price)
   import datetime 
   today = datetime.date.today()  
   import csv 
   header = ['Title','Price','Date']
   data = [title,price,today]

# type(data)
   with open('AmazonWebScraperDataSets.csv','a+',newline='',encoding='UTF8') as f:
     writer = csv.writer(f)
     writer.writerow(header)
     writer.writerow(data)

# %%
while(False):
    check_price()
    time.sleep(5)

# %%
# Out:
#                                                Title  Price        Date
# 0          Pi Day T Shirt Kids Mens Graphic Math ...   13.0  2025-04-19
