# %% [markdown]
# # Web Scraping Using Python

# %% [markdown]
# # What is Web Scraping

# %% [markdown]
# <!-- ______________________________________________ Web Scraping ___________________________________________________________________ -->
# Web scraping is the process of automatically extracting data from websites.
# Instead of manually copying information from a webpage, web scraping uses code (typically in languages like Python) or
# tools to pull the data directly from the website's HTML. This is especially useful when you want to collect large amounts of information like:
#
# Product prices from e-commerce sites
# Job listings from career portals
# News headlines from news sites
# Reviews or ratings from platforms like IMDb or Yelp
#
# Common Tools & Libraries:
# Python:
# BeautifulSoup – for parsing HTML
# Requests – for sending HTTP requests
# Selenium – for interacting with JavaScript-heavy websites
# Scrapy – a powerful web scraping framework
#
# Example Use Case:
# Imagine you want to collect the titles of 100 books from an online bookstore. Instead of copying them one by one, you could write a script to:
#
# Send a request to the website.
# Get the HTML content of the page.
# Parse it to find all the book titles.
# Save them into a file (CSV, Excel, etc.).
#
# Is It Legal?
# Scraping public data is generally okay for personal/educational use.
# But scraping too aggressively or from sites that forbid it (via robots.txt or terms of service) can get your IP banned or lead to legal issues.-->
# # ___________________________________________________________________________________________________________________________

# %% [markdown]
# # Legality of Web Scraping

# %% [markdown]
# ✅ Legal or Generally Acceptable:
# Publicly Available Data
# If the website makes the data available without a login or paywall, and scraping is respectful (i.e., doesn’t overload the server).
# Example: Scraping book titles from a public online bookstore page for academic research.
#
# Permission Granted
# If you have the site owner's permission or if the data is provided via a public API.
#
# ⚠️ Risky or Potentially Illegal:
# Violating Terms of Service (ToS)
# Most websites have rules in their ToS or robots.txt file that prohibit scraping.
# Scraping despite these restrictions could lead to account bans, cease-and-desist letters, or legal action.
#
# Login-Required or Paywalled Content
# Scraping behind authentication (username/password), or behind paywalls is often treated as unauthorized access, which may violate laws like the Computer Fraud and Abuse Act (CFAA) in the U.S.
#
# Personal/Private Information
# Scraping data that includes personal user information (emails, phone numbers, etc.) can breach privacy laws such as GDPR (EU), CCPA (California), or others.
#
# ⚖️ Key Legal Cases (U.S. examples):
# hiQ Labs vs. LinkedIn:
# LinkedIn tried to block hiQ from scraping public profiles.
# Court ruled in favor of hiQ (initially), saying public data could be scraped — but the case sparked huge debate.
#
# 🛡️ Safe Practices:
# Check the robots.txt file of the website (e.g., example.com/robots.txt)
# Respect site’s rate limits (avoid hammering the server)
# Don’t scrape sensitive or private data
# Use available APIs instead of scraping when possible
# <!--____________________________________________________________________________________________________________________________________-->

# %% [markdown]
# # Different Types of Web Scrapers

# %%
#  Self-built Web Scrapers
# Pre-built Web Scrapers
# Browser extensions Web Scrapers
# Software Web Scrapers
# Cloud Web Scrapers

# %% [markdown]
# # Web Scraping Components

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
img = Image.open('component of web scraping .png')

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # Requests Modules

# %%
# The requests module in Python is a powerful and easy-to-use library for sending HTTP/1.1 requests. It allows
# you to interact with web services, fetch data from APIs, send data to servers, and more.

# %%
# pip install requests
import requests

response = requests.get('https://api.github.com')
print(response.status_code)      # Status code (e.g., 200)
print(response.text)             # Raw response text
# print(response.json())           # Parsed JSON (if applicable)
# Out:
# 200
# ...

# %% [raw]
# # ✅ Common Methods
# requests.get(url, params=None, **kwargs)
# requests.post(url, data=None, json=None, **kwargs)
# requests.put()
# requests.delete()
# requests.head()
# requests.patch()

# %%
import requests
web = requests.get("https://www.linkedin.com/")
print(web)
# Out:
# <Response [200]>

# %%
 # Response 
# 200 ---- easily response 
# 300 ---- redirect the page again and again
# 400 ---- working on page and show disallows

# %%
# web.content

# %%
# web.text

# %%
# if you want to see the URL of the sites than use url function or method
web.url
# Out:
# 'https://www.linkedin.com/'

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
# web.status_code
# web.text
# web.content
# web.url
# web.headers
# web.encoding
# web.ok
# web.raise_for_status()
# web.cookies
web.elapsed
# Out:
# datetime.timedelta(microseconds=716919)

# %%
# if  you want to see the response the website than the try this 
web.status_code
# Out:
# 200

# %% [markdown]
# # Parsing the HTML in web page using Python

# %%
soup = BeautifulSoup(web.content,'html.parser')
soup 
# this is parsing the html using the beautiful soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Prettify() function

# %%
# if you want to set or correct the format than you have to use the prettity()
# print(soup.prettify())

# %% [markdown]
# # Some Method using with soup

# %%
# Method	Description
# soup.title	Get the <title> tag
# soup.title.text	Get the text inside <title>
# soup.find('tag')	Find the first occurrence of a tag
# soup.find_all('tag')	Find all occurrences of a tag
# soup.get_text()	Extract all text from the page
# soup.a or soup.find('a')	First hyperlink
# soup.find_all('a')	All hyperlinks (returns a list)
# soup.find('div', class_='classname')	Specific tag with class
# soup.select('css-selector')	CSS selector (powerful!)

# %%
# Let's try to call the image_gen.text2im tool with the prompt.
import requests
from IPython.display import Image, display

# As I don't have direct access to image_gen in this environment, I'll simulate output.
# The code below is representative if image_gen.text2im were available.
prompt = (
    "A clear and legible image of a table titled 'Extended BeautifulSoup Methods & Tricks for Extracting Data' with three columns: "
    "Method / Attribute, Description, and Example. The table contains the following rows:\n"
    "1. Method: tag.name; Description: Get the name of a tag; Example: tag = soup.find('h1'); print(tag.name)\n"
    "2. Method: tag.attrs; Description: Returns all attributes as a dictionary; Example: tag = soup.find('a'); print(tag.attrs)\n"
    "3. Method: tag['href']; Description: Access a specific attribute value; Example: soup.find('a')['href']\n"
    "4. Method: soup.find_all(['h1', 'h2', 'h3']); Description: Find all tags from a list; Example: soup.find_all(['h1', 'h2'])\n"
    "5. Method: soup.find_all('p', limit=3); Description: Get the first 3 matching tags; Example: soup.find_all('p', limit=3)\n"
    "6. Method: soup.find('tag', id='some-id'); Description: Find tag with specific ID; Example: soup.find('div', id='main-content')\n"
    "7. Method: soup.select_one('css-selector'); Description: Return first matching element using CSS selector; Example: soup.select_one('div.article h2')\n"
    "8. Method: soup.select('css-selector'); Description: Return all matching elements using CSS selector; Example: soup.select('ul li a')\n"
    "9. Method: tag.get_text(strip=True); Description: Cleanly extract and strip inner text; Example: tag.get_text(strip=True)\n"
    "10. Method: tag.find_next('tag'); Description: Find the next matching tag after current; Example: soup.find('h1').find_next('p')\n"
    "11. Method: tag.find_previous('tag'); Description: Find the previous tag; Example: soup.find('h2').find_previous('h1')\n"
    "12. Method: tag.parent; Description: Get the parent tag; Example: soup.find('a').parent\n"
    "13. Method: tag.children; Description: Get direct children (returns a generator); Example: for child in tag.children: print(child)\n"
    "14. Method: tag.descendants; Description: Get all nested tags/text recursively; Example: for desc in tag.descendants: print(desc)\n"
    "15. Method: tag.next_sibling; Description: Go to the next sibling in HTML; Example: soup.find('p').next_sibling\n"
    "16. Method: tag.previous_sibling; Description: Go to the previous sibling; Example: soup.find('p').previous_sibling\n"
    "Design: clean, white background, black text, modern sans-serif font, visible borders and alternating row colors for clarity."
)
# Since we can't generate images here, I'll display the prompt as text.
print(prompt)
# If this were a Jupyter environment with image generation capability, we could use image_gen.text2im.
# For example:
# image = image_gen.text2im(prompt=prompt, size="1024x768")
# display(Image(image))
# Out:
# A clear and legible image of a table titled 'Extended BeautifulSoup Methods & Tricks for Extracting Data' with three columns: Method / Attribute, Description, and Example. The table contains the following rows:
# 1. Method: tag.name; Description: Get the name of a tag; Example: tag = soup.find('h1'); print(tag.name)
# 2. Method: tag.attrs; Description: Returns all attributes as a dictionary; Example: tag = soup.find('a'); print(tag.attrs)
# 3. Method: tag['href']; Description: Access a specific attribute value; Example: soup.find('a')['href']
# 4. Method: soup.find_all(['h1', 'h2', 'h3']); Description: Find all tags from a list; Example: soup.find_all(['h1', 'h2'])
# 5. Method: soup.find_all('p', limit=3); Description: Get the first 3 matching tags; Example: soup.find_all('p', limit=3)
# 6. Method: soup.find('tag', id='some-id'); Description: Find tag with specific ID; Example: soup.find('div', id='main-content')
# ...

# %% [markdown]
# <!-- Method / Attribute | Description | Example
# tag.name | Get the name of a tag | tag = soup.find('h1'); print(tag.name)
# tag.attrs | Returns all attributes as a dictionary | tag = soup.find('a'); print(tag.attrs)
# tag['href'] | Access a specific attribute value | soup.find('a')['href']
# soup.find_all(['h1', 'h2', 'h3']) | Find all tags from a list | soup.find_all(['h1', 'h2'])
# soup.find_all('p', limit=3) | Get the first 3 matching tags | soup.find_all('p', limit=3)
# soup.find('tag', id='some-id') | Find tag with specific ID | soup.find('div', id='main-content')
# soup.select_one('css-selector') | Return first matching element using CSS selector | soup.select_one('div.article h2')
# soup.select('css-selector') | Return all matching elements using CSS selector | soup.select('ul li a')
# tag.get_text(strip=True) | Cleanly extract and strip inner text | tag.get_text(strip=True)
# tag.find_next('tag') | Find the next matching tag after current | soup.find('h1').find_next('p')
# tag.find_previous('tag') | Find the previous tag | soup.find('h2').find_previous('h1')
# tag.parent | Get the parent tag | soup.find('a').parent
# tag.children | Get direct children (returns a generator) | for child in tag.children: print(child)
# tag.descendants | Get all nested tags/text recursively | for desc in tag.descendants: print(desc)
# tag.next_sibling | Go to the next sibling in HTML | soup.find('p').next_sibling
# tag.previous_sibling | Go to the previous sibling | soup.find('p').previous_sibling -->

# %%
# Method / Attribute | Description | Example
# tag.name | Get the name of a tag | tag = soup.find('h1'); print(tag.name)
# tag.attrs | Returns all attributes as a dictionary | tag = soup.find('a'); print(tag.attrs)
# tag['href'] | Access a specific attribute value | soup.find('a')['href']
# soup.find_all(['h1', 'h2', 'h3']) | Find all tags from a list | soup.find_all(['h1', 'h2'])
# soup.find_all('p', limit=3) | Get the first 3 matching tags | soup.find_all('p', limit=3)
# soup.find('tag', id='some-id') | Find tag with specific ID | soup.find('div', id='main-content')
# soup.select_one('css-selector') | Return first matching element using CSS selector | soup.select_one('div.article h2')
# soup.select('css-selector') | Return all matching elements using CSS selector | soup.select('ul li a')
# tag.get_text(strip=True) | Cleanly extract and strip inner text | tag.get_text(strip=True)
# tag.find_next('tag') | Find the next matching tag after current | soup.find('h1').find_next('p')
# tag.find_previous('tag') | Find the previous tag | soup.find('h2').find_previous('h1')
# tag.parent | Get the parent tag | soup.find('a').parent
# tag.children | Get direct children (returns a generator) | for child in tag.children: print(child)
# tag.descendants | Get all nested tags/text recursively | for desc in tag.descendants: print(desc)
# tag.next_sibling | Go to the next sibling in HTML | soup.find('p').next_sibling
# tag.previous_sibling | Go to the previous sibling | soup.find('p').previous_sibling

# %%
tag = soup.find('h1'); print(tag.name)
tag.text
# Out:
# h1
# 'High-Quality, Practical-based, Free Tutorials'

# %%
all = soup.find_all(['h1', 'h2'])
all
# Out:
# [<h1 class="main-heading my-3">High-Quality, Practical-based, Free Tutorials</h1>,
#  <h2 class="section-heading my-2">Most Popular Tutorials</h2>,
#  <h2 class="section-heading">Online Compilers for Seamless Practice</h2>,
#  <h2 class="section-heading my-2">Land Your Dream Job By Preparing for Interview Questions</h2>,
#  <h2 class="section-heading my-2">Challenge Yourself With Free Quizzes</h2>,
#  <h2 class="section-heading my-2">Programming Examples For Practice</h2>,
#  <h2 class="section-heading my-2 text-capitalize">UpSkill With Live online courses</h2>,
#  <h2 class="section-heading mb-md-3">Create your free account now on Tutorials Freak and unlock the entire content!</h2>,
#  <h2 class="section-heading">Get Tutorials Freak Mobile App to Learn on The Go!</h2>]

# %%
 for child in tag.children: print(child)
# Out:
# High-Quality, Practical-based, Free Tutorials

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>My Website</title></head>
<body>
  <h1>Welcome</h1>
  <p class="content">This is a test paragraph.</p>
  <a href="http://example.com">Visit Example</a>
</body></html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# Get the title
print(soup.title.text)

# Get the first paragraph
print(soup.find('p').text)

# Get the link href
print(soup.a['href'])
# Out:
# My Website
# This is a test paragraph.
# http://example.com

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://data.gov/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# for link in soup.find_all('a'):
#     print(link.get('href'))

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
soup = BeautifulSoup(web.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
web = requests.get("https://www.tutorialsfreak.com/")

# Parse the HTML content
soup = BeautifulSoup(web.text, 'html.parser')

# Retrieve all text data from the website
all_text = soup.get_text(separator='\n', strip=True)

# Print the extracted text
print(all_text)
# Out:
# Tutorials Freak: Free Online Tutorials to Learn & Upskill
# Learn & Upskill With
# High-Quality, Practical-based, Free Tutorials
# Kickstart effective learning with Tutorials Freak, with new content published every day.
# Start Learning!
# Verified & Reliable Content
# The entire content on the site is verified by pro developers and tech freaks.
# Self-Directed Learning
# The entire content on the site is verified by pro developers and tech freaks. Enabling self-directed learning so that you can learn at your pace and shape your own path.
# Dual Learning Methods
# Along with simplified tutorials, you get video content created by industry experts.
# Our Unique Approach
# Why Tutorials Freak?
# Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.
# Get Started Now
# Content Learners Love
# Most Popular Tutorials
# ...

# %%
soup.h1
# Out:
# <h1 class="main-heading my-3">High-Quality, Practical-based, Free Tutorials</h1>

# %% [markdown]
# # Kind of Object Beautifulsoup in web scraping

# %%
#------  kind of object------
# tag
# Navigable string
# Beautiful
# comment

# %%
# Object Type	  Description	                Example
# BeautifulSoup	  Entire HTML/XML document	     soup = BeautifulSoup(...)
# Tag	          An individual HTML/XML tag	 soup.div, soup.a
# NavigableString  	Text within a tag	         soup.title.string
# Comment	      HTML comment                     <!-- This is a comment -->
# ResultSet     	A list-like result from find_all()	 soup.find_all('a')

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
soup = BeautifulSoup(web.content,'html.parser')
# soup

# %% [markdown]
# # Tag

# %%
# # Represents an individual HTML or XML tag.
# soup.h1  #also h2 and h3 and so on.
# soup.a
# soup.img
# soup.body
# soup.meta
# soup.div

# %% [markdown]
# Sure! Here's a **table of common `Tag` object functions and attributes** in BeautifulSoup, with descriptions and examples:
#
# ---
#
# ### 🔹 **BeautifulSoup Tag Object – Functions & Attributes Table**
#
# | **Function / Attribute**        | **Description**                                     | **Example**                            |
# |----------------------------------|-----------------------------------------------------|----------------------------------------|
# | `tag.name`                      | Get the tag name                                    | `tag.name → 'a'`                        |
# | `tag.attrs`                     | Get all attributes as a dictionary                  | `tag.attrs → {'href': 'link'}`         |
# | `tag['attr']`                   | Access specific attribute                           | `tag['href'] → 'link'`                 |
# | `tag.string`                    | Get the text inside the tag                         | `tag.string → 'Hello'`                 |
# | `tag.get_text()` or `tag.text` | Get all inner text (including nested)               | `tag.get_text() → 'Click here'`        |
# | `tag.contents`                 | List of direct children (Tags and Strings)          | `tag.contents → [<b>Click</b>, ' here']` |
# | `tag.children`                 | Iterator for direct children                        | `for child in tag.children: ...`       |
# | `tag.descendants`             | Iterator for all nested elements                    | `for d in tag.descendants: ...`        |
# | `tag.parent`                   | Get the parent tag                                  | `tag.parent.name → 'div'`              |
# | `tag.parents`                  | Iterator over all parent tags                       | `for p in tag.parents: ...`            |
# | `tag.next_sibling`             | Next sibling in HTML                                | `tag.next_sibling`                     |
# | `tag.previous_sibling`         | Previous sibling in HTML                            | `tag.previous_sibling`                 |
# | `tag.find(name)`               | Find first matching nested tag                      | `tag.find('a')`                        |
# | `tag.find_all(name)`          | Find all matching nested tags                       | `tag.find_all('a')`                    |
# | `tag.has_attr('attr')`         | Check if tag has an attribute                       | `tag.has_attr('href') → True`          |
# | `tag['attr'] = 'value'`        | Set or modify an attribute                          | `tag['class'] = 'active'`              |
# | `del tag['attr']`              | Delete an attribute                                 | `del tag['href']`                      |
# | `tag.clear()`                  | Remove all tag content                              | `tag.clear()`                          |
#
# ---

# %%
h1_tag = soup.h1
# tag

# %%
h1_tag = soup.html
print(type(tag))
# Out:
# <class 'bs4.element.Tag'>

# %%
# Find all <h1> tags and loop through them
for h1_tag in soup.find_all('h4'):    #h1 , h2 ,h3 and also h4 
    print(h1_tag.text)
# Out:
# Why Tutorials Freak?

# %% [markdown]
# # Navigable string

# %%
# this means the paragrah inside of any tag it called navigable string

# %%
tag = soup.p.string
tag
# Out:
# 'Kickstart effective learning with Tutorials Freak, with new content published every day.'

# %%
tag = soup.h2.string
tag
# Out:
# 'Most Popular Tutorials'

# %% [markdown]
# # BeaitfulSoup

# %%
# is use for soup creation such like this 
soup = BeautifulSoup(web.content,'html.parser')
# soup

# %%
# soup.name
# soup.title
# soup.head
# soup.footer
# soup.body

# %% [raw]
# Absolutely! Here's a clean and well-organized **table of commonly accessed HTML tags using BeautifulSoup** 👇
#
# ---
#
# ### 🔹 **BeautifulSoup – Accessing Common HTML Tags (Table Format)**
#
# | **Code**                | **Description**                            | **Example Output**                           |
# |-------------------------|--------------------------------------------|----------------------------------------------|
# | `soup.title`            | First `<title>` tag                        | `<title>My Website</title>`                  |
# | `soup.title.text`       | Text inside the `<title>` tag              | `My Website`                                 |
# | `soup.head`             | Entire `<head>` section                    | `<head>...</head>`                           |
# | `soup.body`             | Entire `<body>` section                    | `<body>...</body>`                           |
# | `soup.header`           | First `<header>` tag                       | `<header>Header Content</header>`            |
# | `soup.footer`           | First `<footer>` tag                       | `<footer>Footer Info</footer>`               |
# | `soup.h1`               | First `<h1>` tag                           | `<h1>Heading 1</h1>`                          |
# | `soup.h2`, `soup.h3`    | First `<h2>`, `<h3>` tags                  | `<h2>Heading 2</h2>`                          |
# | `soup.p`                | First `<p>` (paragraph) tag                | `<p>This is a paragraph</p>`                 |
# | `soup.a`                | First `<a>` (anchor/hyperlink)             | `<a href="url">Link</a>`                     |
# | `soup.ul` / `soup.ol`   | First unordered / ordered list             | `<ul><li>Item</li></ul>`                     |
# | `soup.li`               | First `<li>` list item                     | `<li>List item</li>`                         |
# | `soup.div`              | First `<div>` container                    | `<div class="box">Content</div>`             |
# | `soup.span`             | First `<span>` tag                         | `<span>Inline Text</span>`                   |
# | `soup.img`              | First `<img>` image tag                    | `<img src="image.jpg" alt="img">`            |
# | `soup.form`             | First `<form>` tag                         | `<form action="/submit">...</form>`          |
# | `soup.input`            | First `<input>` field                      | `<input type="text" name="email">`           |
# | `soup.button`           | First `<button>` tag                       | `<button>Submit</button>`                    |
# | `soup.nav`              | First `<nav>` tag                          | `<nav>Navigation links</nav>`                |
# | `soup.section`          | First `<section>` tag                      | `<section>Main Section</section>`            |
# | `soup.article`          | First `<article>` tag                      | `<article>Blog Post</article>`               |
# | `soup.main`             | First `<main>` content tag                 | `<main>Page Content</main>`                  |
#
# ---
#
# ### ✅ Want to Get All Tags of the Same Type?
#
# Use `find_all()`:
#
# ```python
# soup.find_all('h1')      # List of all <h1> tags
# soup.find_all('a')       # List of all <a> (links)
# ```
#
# ---

# %% [markdown]
# # Soup Function use for performing tasks

# %% [raw]
# Sure! Here's a **table of commonly used functions of the `soup` object** in **BeautifulSoup**, which help you extract and navigate through HTML content 🔍
#
# ---
#
# ## 🔹 **BeautifulSoup `soup` Object – Functions Table**
#
# | **Function / Method**           | **Description**                                                 | **Example**                                      |
# |----------------------------------|------------------------------------------------------------------|--------------------------------------------------|
# | `soup.find(name)`               | Finds the **first** occurrence of a tag                         | `soup.find('p')` → First `<p>` tag               |
# | `soup.find_all(name)`           | Finds **all** matching tags                                     | `soup.find_all('a')` → List of all `<a>` tags    |
# | `soup.select(selector)`         | Finds tags using **CSS selectors**                              | `soup.select('div.content')`                     |
# | `soup.select_one(selector)`     | Finds the **first match** using CSS selector                    | `soup.select_one('h1.title')`                    |
# | `soup.get_text()`               | Extracts all text from the HTML                                 | `soup.get_text()`                                |
# | `soup.prettify()`               | Returns the HTML in a nicely indented (pretty) format           | `print(soup.prettify())`                         |
# | `soup.contents`                 | Returns the direct children (tags + strings) of the tag         | `soup.body.contents`                             |
# | `soup.children`                 | Iterator over direct children                                   | `for child in soup.children: ...`                |
# | `soup.descendants`              | Iterator over all children and sub-children                     | `for tag in soup.descendants: ...`               |
# | `soup.parent`                   | Returns the parent tag                                          | `soup.title.parent`                              |
# | `soup.parents`                  | Generator for all parents up the tree                           | `for p in soup.title.parents: ...`               |
# | `soup.next_sibling`             | Returns next sibling in HTML                                    | `soup.h1.next_sibling`                           |
# | `soup.previous_sibling`         | Returns previous sibling                                        | `soup.h1.previous_sibling`                       |
# | `soup.find_parent()`            | Finds closest parent of tag                                     | `soup.a.find_parent('div')`                      |
# | `soup.find_parents()`           | Finds all parents of tag                                        | `soup.a.find_parents()`                          |
#
# ---
#
# ### ✅ Example Code:
# ```python
# from bs4 import BeautifulSoup
#
# html = "<html><body><h1>Title</h1><p>Hello <a href='#'>World</a></p></body></html>"
# soup = BeautifulSoup(html, 'html.parser')
#
# print(soup.find('h1').text)           # Title
# print(soup.find_all('a'))             # [<a href='#'>World</a>]
# print(soup.select('p a'))             # [<a href='#'>World</a>]
# print(soup.get_text())                # Title Hello World
# ```
#
# ---

# %%
soup.find('p')
# Out:
# <p class="section-subheading">Kickstart effective learning with Tutorials Freak, with new content published every day.</p>

# %%
soup.find_all('h2')
# Out:
# [<h2 class="section-heading my-2">Most Popular Tutorials</h2>,
#  <h2 class="section-heading">Online Compilers for Seamless Practice</h2>,
#  <h2 class="section-heading my-2">Land Your Dream Job By Preparing for Interview Questions</h2>,
#  <h2 class="section-heading my-2">Challenge Yourself With Free Quizzes</h2>,
#  <h2 class="section-heading my-2">Programming Examples For Practice</h2>,
#  <h2 class="section-heading my-2 text-capitalize">UpSkill With Live online courses</h2>,
#  <h2 class="section-heading mb-md-3">Create your free account now on Tutorials Freak and unlock the entire content!</h2>,
#  <h2 class="section-heading">Get Tutorials Freak Mobile App to Learn on The Go!</h2>]

# %%
h3 = soup.find_all('h3')
h3
# Out:
# [<h3 class="fs-20 lh-30 fw-600 label-color-5">Verified &amp; Reliable Content</h3>,
#  <h3 class="fs-20 lh-30 fw-600 label-color-5">Self-Directed Learning</h3>,
#  <h3 class="fs-20 lh-30 fw-600 label-color-5">Dual Learning Methods</h3>,
#  <h3 class="fs-16 lh-30 fw-500 label-color-5 my-1 heading-turnicate" title="jQuery Interview Questions">jQuery Interview Questions</h3>,
#  <h3 class="fs-16 lh-30 fw-500 label-color-5 my-1 heading-turnicate" title="PHP Interview Questions">PHP Interview Questions</h3>,
#  <h3 class="fs-16 lh-30 fw-500 label-color-5 my-1 heading-turnicate" title="Git Interview Questions">Git Interview Questions</h3>,
#  <h3 class="fs-16 lh-30 fw-500 label-color-5 my-1 heading-turnicate" title="ReactJS Interview Questions">ReactJS Interview Questions</h3>,
#  <h3 class="fs-16 lh-30 fw-500 label-color-5 my-1 heading-turnicate" title="Web App Penetration Testing Interview Questions">Web App Penetration Testing Interview Questions</h3>,
# ...

# %% [markdown]
# # Comments

# %%
comm = soup.p.string
comm
# Out:
# 'Kickstart effective learning with Tutorials Freak, with new content published every day.'

# %%
comm = soup.p.prettify
comm
# Out:
# <bound method Tag.prettify of <p class="section-subheading">Kickstart effective learning with Tutorials Freak, with new content published every day.</p>>

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <noscript>
#   <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PC6BJKM8" style="display:none;visibility:hidden" width="0">
#   </iframe>
#  </noscript>
#  <div id="__next">
#   <div class="Toastify">
#   </div>
#   <div class="wrapperr h-100">
#    <header class="header-section d-flex align-items-lg-center px-xl-5 px-4 position-fixed w-100 bg-white header-new-padding">
#     <div class="header-bottom-line">
#     </div>
#     <nav class="w-100 navbar navbar-expand-lg navbar-light">
#      <div class="px-0 container-fluid">
#       <a class="header-logo-wrapper" href="/">
#        <span class="me-lg-5 navbar-brand">
#         <span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%">
# ...

# %% [markdown]
# # Finding Elements in web page using python

# %%
# _______-__________ Finding Elements_________________________________
# Finding Elements by class
# Finding Elements by ID

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
# web.content
# web.status_code
soup = BeautifulSoup(web.content,"html.parser")
# soup
# # in structure format form 
# print(soup.body.prettify())

# %% [markdown]
# # finding Element by Class

# %%
class_data = soup.find('div',class_ = "px-0 container-fluid")
class_data
# Out:
# <div class="px-0 container-fluid"><a class="header-logo-wrapper" href="/"><span class="me-lg-5 navbar-brand"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;m
# ...

# %%
# class_data.find_all('p')
# class_data.find_all('h1')
class_data.find_all('h2')
# class_data.find_all('h3')
# Out:
# []

# %% [markdown]
# # finding Element by id

# %%
id_data = soup.find('div',id ="__next")
id_data
# Out:
# <div id="__next"><div class="Toastify"></div><div class="wrapperr h-100"><header class="header-section d-flex align-items-lg-center px-xl-5 px-4 position-fixed w-100 bg-white header-new-padding"><div class="header-bottom-line"></div><nav class="w-100 navbar navbar-expand-lg navbar-light"><div class="px-0 container-fluid"><a class="header-logo-wrapper" href="/"><span class="me-lg-5 navbar-brand"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0
# ...

# %%
class_data = soup.find('a',class_ = "text-decoration-none")
class_data
# Out:
# <a class="text-decoration-none" href="/search"><input aria-label="Search" class="label-color-1 fw-500 fs-16 lh-24 bg-grey form-control" placeholder="Search" type="text"/><span><img alt="Serch-Img" src="/images/search.svg"/></span></a>

# %%
soup.find_all('a')
# soup.find_all('h1')
# soup.find_all('h2')
# Out:
# [<a class="header-logo-wrapper" href="/"><span class="me-lg-5 navbar-brand"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>
# ...

# %% [markdown]
# # Extracting Text from the tags in Web Page using python

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
web
soup = BeautifulSoup(web.content,'html.parser')
# print(soup.prettify())

# %%
lines = soup.find_all('p')
lines
# Out:
# [<p class="section-subheading">Kickstart effective learning with Tutorials Freak, with new content published every day.</p>,
#  <p class="fs-16 fw-400 lh-24 label-color-1 card-text">The entire content on the site is verified by pro developers and tech freaks.</p>,
#  <p class="fs-16 fw-400 lh-24 label-color-1 card-text">The entire content on the site is verified by pro developers and tech freaks. Enabling self-directed learning so that you can learn at your pace and shape your own path.</p>,
#  <p class="fs-16 fw-400 lh-24 label-color-1 card-text">Along with simplified tutorials, you get video content created by industry experts.</p>,
#  <p class="fw-400 fs-20 lh-30 label-color-2 mb-lg-5">Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.</p>,
#  <p class="section-subheading mb-0">Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.</p>,
# ...

# %%
# if you want to extract all the text in a paragrah then we this line
for i in lines:
    print(i.text)
# Out:
# Kickstart effective learning with Tutorials Freak, with new content published every day.
# The entire content on the site is verified by pro developers and tech freaks.
# The entire content on the site is verified by pro developers and tech freaks. Enabling self-directed learning so that you can learn at your pace and shape your own path.
# Along with simplified tutorials, you get video content created by industry experts.
# Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.
# Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.
# Explore the expert-curated interview questions with answers.
# Plenty of quizzes with time duration and skill assessment.
# Find coding examples with programs, output, easy explanations, and videos.
#
# With an account, you get access to premium content and courses at no cost.
# ...

# %%
lines = soup.find_all('div')
lines
# Out:
# [<div id="__next"><div class="Toastify"></div><div class="wrapperr h-100"><header class="header-section d-flex align-items-lg-center px-xl-5 px-4 position-fixed w-100 bg-white header-new-padding"><div class="header-bottom-line"></div><nav class="w-100 navbar navbar-expand-lg navbar-light"><div class="px-0 container-fluid"><a class="header-logo-wrapper" href="/"><span class="me-lg-5 navbar-brand"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:
# ...

# %%
for i in lines:
    print(i.text)
# Out:
# Learn & Upskill WithHigh-Quality, Practical-based, Free TutorialsKickstart effective learning with Tutorials Freak, with new content published every day.Start Learning!Verified & Reliable ContentThe entire content on the site is verified by pro developers and tech freaks.Self-Directed LearningThe entire content on the site is verified by pro developers and tech freaks. Enabling self-directed learning so that you can learn at your pace and shape your own path.Dual Learning MethodsAlong with simplified tutorials, you get video content created by industry experts.Our Unique ApproachWhy Tutorials Freak?Learning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.Get Started NowContent Learners LoveMost Popular TutorialsLearning programming and technical things can be complex. We are here to make it easy with simple and interactive tutorials.Loading...Loading...Loading...Loading...View All TutorialsOnline Compilers for Seamles
# ...

# %%
s = soup.find('span',class_="fs-13 fw-500 label-color-4 text-truncate")
s
# Out:
# <span class="fs-13 fw-500 label-color-4 text-truncate">Start Coding C<svg aria-hidden="true" class="svg-inline--fa fa-arrow-right ms-2" data-icon="arrow-right" data-prefix="fas" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M438.6 278.6l-160 160C272.4 444.9 264.2 448 256 448s-16.38-3.125-22.62-9.375c-12.5-12.5-12.5-32.75 0-45.25L338.8 288H32C14.33 288 .0016 273.7 .0016 256S14.33 224 32 224h306.8l-105.4-105.4c-12.5-12.5-12.5-32.75 0-45.25s32.75-12.5 45.25 0l160 160C451.1 245.9 451.1 266.1 438.6 278.6z" fill="currentColor"></path></svg></span>

# %%
lines_h3= soup.find_all('h3')
# lines_h3

# %%
for i in lines_h3:
    print(i.text)
# Out:
# Verified & Reliable Content
# Self-Directed Learning
# Dual Learning Methods
# jQuery Interview Questions
# PHP Interview Questions
# Git Interview Questions
# ReactJS Interview Questions
# Web App Penetration Testing Interview Questions
# IoT Interview Questions
# Google Analytics Interview Questions
# Java Interview Questions
# Python Interview Questions
# Android Penetration Testing Interview Questions
# Ethical Hacking Interview Questions
# Nmap Interview Questions
# Google Ads Interview Questions
# ReactJS Quiz
# Web App Penetration Testing Quiz
# IoT Quiz
# Python Quiz
# Android Penetration Testing Quiz
# Ethical Hacking Quiz
# SEO Quiz
# Java Programs
# Python Programs
# Full Stack Web Development Course
# Digital Marketing Course
# SEO Course
# Python Certification Course
# Data Analytics Course
# Ethical Hacking Course

# %% [markdown]
# # Extracting Links in Web Page Using Python

# %%
links = soup.find_all('a')
links
# Out:
# [<a class="header-logo-wrapper" href="/"><span class="me-lg-5 navbar-brand"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>
# ...

# %%
for i in links:
    print(i.get('href'))
# Out:
# /
# /search
# /
# /
# /
# /
# /
# /
# /
# /
# /compiler/c
# /compiler/css
# /compiler/html
# /compiler/jquery
# /compiler/cpp
# /compiler/php
# /compiler/python
# https://bit.ly/web-developer-course-ws
# https://bit.ly/web-developer-course-ws
# https://bit.ly/digital-marketing-course-ws
# https://bit.ly/digital-marketing-course-ws
# https://bit.ly/seo-course-ws
# https://bit.ly/seo-course-ws
# https://www.wscubetech.com/online-python-certification-course-india.html?utm_source=TutorialsFreak&utm_medium=python-tutorial&utm_campaign=leads
# https://www.wscubetech.com/online-python-certification-course-india.html?utm_source=TutorialsFreak&utm_medium=python-tutorial&utm_campaign=leads
# https://www.wscubetech.com/online-data-analytics-course.html?utm_source=TutorialsFreak&utm_medium=ai-tutorial&utm_campaign=leads
# https://www.wscubetech.com/online-data-analytics-course.html?utm_source=TutorialsFreak&utm_medium=ai-tutorial&utm_campaign=leads
# ...

# %% [markdown]
# # Extracting Image Information in Web Page using the Python

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.tutorialsfreak.com/")
web
soup = BeautifulSoup(web.content,'html.parser')
# print(soup.prettify())

# %%
image = soup.find_all('img')
print(image)
# Out:
# [<img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>, <img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>, <img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" loading="lazy" src="/images/tutorials-freak-logo.svg" srcset="/images/tutorials-freak-logo.svg 1x, /images/tutorials-freak-logo.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100
# ...

# %%
for i in image:
    print(i.get('src'))
# Out:
# data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e
# ...-freak-logo.svg
# /images/search.svg
# ..._next/image?url=%2Fimages%2Fbanner-middle.webp&w=3840&q=75
# /images/kotlin-img.svg
# /images/eagle-img.svg
# /images/apple-img.svg
# /images/angular-img.svg
# /images/python-img.svg
# /images/react-img.svg
# /images/android-img.svg
# /images/java-img.svg
# data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%2748%27%20height=%2748%27/%3e
# ...://d20evgacl8spoj.cloudfront.net/uploads/learning-course/images/home-page/2cd6e0d7-4864-4837-a4a7-e0b120282e8d-1648197173.svg
# data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%2748%27%20height=%2748%27/%3e
# ...://d20evgacl8spoj.cloudfront.net/uploads/learning-course/images/home-page/e5eb78ac-30fd-4443-8f23-63bd378c0c01-1645691302.svg
# ...

# %%
image = soup.find_all('img')
print(image)
# Out:
# [<img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27192%27%20height=%2756%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>, <img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>, <img alt="Logo-Img" class="img-fluid" data-nimg="intrinsic" decoding="async" loading="lazy" src="/images/tutorials-freak-logo.svg" srcset="/images/tutorials-freak-logo.svg 1x, /images/tutorials-freak-logo.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100
# ...

# %%
for i in image:
    print(i.get('alt'))
# Out:
# Logo-Img
# Logo-Img
# Serch-Img
# Banner-Img
# Banner-Img
# Course-Img
# Course-Img
# Course-Img
# Course-Img
# Course-Img
# Course-Img
# Course-Img
# Course-Img
#
# Why-Choose-Img
# Why-Choose-Img
#
# Why-Choose-Img
# Why-Choose-Img
#
# Why-Choose-Img
# Why-Choose-Img
#
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
#
# compiler-img
# compiler-img
# https://d20evgacl8spoj.cloudfront.net/uploads/learning-course/images/lcourses/861b734d-1200-4ef9-9f80-fdcbf2d5918b-1654781169.png
# https://d20evgacl8spoj.cloudfront.net/uploads/learning-course/images/lcourses/99334bcb-06ec-402d-8461-a1d886d97b8e-1654319072.png
# https://d20evgacl8spoj.cloudfront.net/uploads/learning-course/images/lcourses/28a317b0-5132-4aba-8a49-5ea970f23a49-1671862480.png
# ...
